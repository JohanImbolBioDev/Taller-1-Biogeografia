# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohanImbolBioDev/Taller-1-Biogeografia/blob/main/Descargar_abundancias.ipynb)

# %% [markdown]
# # Descargar abundacias de especies o generos

# %%
# %pip install pandas  openpyxl pygbif
# Out:
# Requirement already satisfied: pandas in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.0.5)
# Requirement already satisfied: geopandas in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (1.1.4)
# Requirement already satisfied: matplotlib in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.11.1)
# Requirement already satisfied: openpyxl in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.1.5)
# Requirement already satisfied: pygbif in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (0.6.6)
# Requirement already satisfied: numpy>=2.3.3 in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from geopandas) (0.13.0)
# Requirement already satisfied: packaging in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from geopandas) (26.1)
# Requirement already satisfied: pyproj>=3.5.0 in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from geopandas) (3.8.0)
# Requirement already satisfied: shapely>=2.0.0 in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from geopandas) (2.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: pillow>=9 in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: et-xmlfile in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: requests>2.7 in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pygbif) (2.33.1)
# Requirement already satisfied: requests-cache in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pygbif) (1.3.3)
# Requirement already satisfied: geojson_rewind in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pygbif) (1.2.1)
# Requirement already satisfied: geomet in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pygbif) (1.1.0)
# Requirement already satisfied: appdirs>=1.4.3 in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pygbif) (1.4.4)
# Requirement already satisfied: certifi in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pyogrio>=0.7.2->geopandas) (2026.2.25)
# Requirement already satisfied: six>=1.5 in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>2.7->pygbif) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>2.7->pygbif) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>2.7->pygbif) (2.6.3)
# Requirement already satisfied: click in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from geomet->pygbif) (8.5.0)
# Requirement already satisfied: attrs>=21.2 in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests-cache->pygbif) (26.1.0)
# Requirement already satisfied: cattrs>=22.2 in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests-cache->pygbif) (26.2.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests-cache->pygbif) (4.11.8)
# Requirement already satisfied: url-normalize>=2.0 in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests-cache->pygbif) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.14.0 in c:\Users\USUARIO\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from cattrs>=22.2->requests-cache->pygbif) (4.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pygbif import species

resultado = species.name_backbone(scientificName="Atelopus", # Cambia Atelopus por tu busqueda
                                  taxonRank="GENUS",   # Cambia el nivel taxonomico de la busqueda que quieres hacer (revisar pygbif )
                                  family="Bufonidae")  # opcional para una busqueda más rapida y especifica

resultado
# Out:
# {'usage': {'key': '2422265',
#   'name': 'Atelopus Duméril & Bibron, 1841',
#   'canonicalName': 'Atelopus',
#   'authorship': 'Duméril & Bibron, 1841',
#   'rank': 'GENUS',
#   'code': 'ZOOLOGICAL',
#   'status': 'ACCEPTED',
#   'type': 'SCIENTIFIC',
#   'formattedName': '<i>Atelopus</i> Duméril & Bibron, 1841'},
#  'classification': [{'key': '1', 'name': 'Animalia', 'rank': 'KINGDOM'},
#   {'key': '44', 'name': 'Chordata', 'rank': 'PHYLUM'},
#   {'key': '131', 'name': 'Amphibia', 'rank': 'CLASS'},
#   {'key': '952', 'name': 'Anura', 'rank': 'ORDER'},
#   {'key': '6727', 'name': 'Bufonidae', 'rank': 'FAMILY'},
#   {'key': '2422265', 'name': 'Atelopus', 'rank': 'GENUS'}],
#  'diagnostics': {'matchType': 'EXACT',
#   'confidence': 100,
#   'timeTaken': 40,
#   'timings': {'nameNRank': 0,
#    'sciNameMatch': 40,
#    'nameParse': 0,
#    'luceneMatch': 40}},
#  'synonym': False,
#  'left': 1025918,
#  'right': 1026025}

# %%
from pygbif import occurrences as occ
import pandas as pd
import time


def descargar_registros_especie(
    taxon_key,
    nombre_especie
):

    registros = []

    offset = 0
    limit = 300


    while True:

        respuesta = occ.search(

            taxonKey=int(taxon_key),

            country="CO",

            hasCoordinate=True,

            limit=limit,

            offset=offset
        )


        resultados = respuesta[
            "results"
        ]


        if len(resultados) == 0:

            break


        for registro in resultados:

            registro[
                "especie_consulta"
            ] = nombre_especie


            registros.append(
                registro
            )


        print(
            f"{nombre_especie}: "
            f"{len(registros)} registros"
        )


        if len(resultados) < limit:

            break


        offset += limit

        time.sleep(0.2)


    return registros

# %%
registros_totales = descargar_registros_especie(resultado['usage']['key'], "Atelopus")
# Out:
# Atelopus: 300 registros
# Atelopus: 600 registros
# Atelopus: 900 registros
# Atelopus: 1200 registros
# Atelopus: 1401 registros

# %%
df_registros = pd.DataFrame(
    registros_totales
)

# %%
df_registros.head()
# Out:
#           key                            datasetKey  \
# 0  6133321895  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 1  6163002180  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 2  6234955645  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 3  6235651099  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 4  6400598488  50c9509d-22c7-4a22-a47d-8c48425ef4a7
#
#                        publishingOrgKey   datasetCategory  \
# 0  28eb1a3f-1c15-4a95-931a-4af90ecb574d  [CitizenScience]
# 1  28eb1a3f-1c15-4a95-931a-4af90ecb574d  [CitizenScience]
# 2  28eb1a3f-1c15-4a95-931a-4af90ecb574d  [CitizenScience]
# 3  28eb1a3f-1c15-4a95-931a-4af90ecb574d  [CitizenScience]
# 4  28eb1a3f-1c15-4a95-931a-4af90ecb574d  [CitizenScience]
#
#                         installationKey                hostingOrganizationKey  \
# 0  997448a8-f762-11e1-a439-00145eb45e9a  28eb1a3f-1c15-4a95-931a-4af90ecb574d
# 1  997448a8-f762-11e1-a439-00145eb45e9a  28eb1a3f-1c15-4a95-931a-4af90ecb574d
# 2  997448a8-f762-11e1-a439-00145eb45e9a  28eb1a3f-1c15-4a95-931a-4af90ecb574d
# 3  997448a8-f762-11e1-a439-00145eb45e9a  28eb1a3f-1c15-4a95-931a-4af90ecb574d
# 4  997448a8-f762-11e1-a439-00145eb45e9a  28eb1a3f-1c15-4a95-931a-4af90ecb574d
#
#   publishingCountry     protocol                    lastCrawled  \
# 0                US  DWC_ARCHIVE  2026-08-28T18:34:26.589+00:00
# 1                US  DWC_ARCHIVE  2026-08-28T18:34:26.589+00:00
# 2                US  DWC_ARCHIVE  2026-08-28T18:34:26.589+00:00
# 3                AR  DWC_ARCHIVE  2026-08-28T18:34:26.589+00:00
# 4                CO  DWC_ARCHIVE  2026-08-28T18:34:26.589+00:00
#
#                       lastParsed  ...  http://unknown.org/orphanEndpoint  \
# 0  2026-09-02T08:36:06.908+00:00  ...                                NaN
# 1  2026-09-02T09:27:03.626+00:00  ...                                NaN
# 2  2026-09-02T08:02:46.039+00:00  ...                                NaN
# 3  2026-09-02T09:05:29.654+00:00  ...                                NaN
# 4  2026-09-02T08:00:01.263+00:00  ...                                NaN
#
#   coordinatePrecision locationRemarks typifiedName  \
# 0                 NaN             NaN          NaN
# 1                 NaN             NaN          NaN
# 2                 NaN             NaN          NaN
# 3                 NaN             NaN          NaN
# 4                 NaN             NaN          NaN
#
#   http://unknown.org/conceptualSchema  http://unknown.org/declaredCount  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
#
#    associatedReferences  associatedSequences  taxonConceptID  \
# 0                   NaN                  NaN             NaN
# 1                   NaN                  NaN             NaN
# 2                   NaN                  NaN             NaN
# 3                   NaN                  NaN             NaN
# 4                   NaN                  NaN             NaN
#
#    http://unknown.org/datasetCategory.gbif.org
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
# [5 rows x 176 columns]

# %%
df_registros.to_csv(
    "Datos/registros_gbif_raw_atelopus.csv",
    index=False
)

# %% [markdown]
# Los datos descargados contienen muchas columnas que no necesitamos. Por lo que seleccionamos solo las que bos sirven

# %%
columnas = [

    "key",

    "scientificName",

    "species",

    "decimalLatitude",

    "decimalLongitude",

    "stateProvince",

    "municipality",

    "basisOfRecord",

    "year",

    "datasetKey",

    "datasetName",

    "institutionCode",

    "collectionCode",

    "coordinateUncertaintyInMeters",

    "hasGeospatialIssues",

    "issues",

    "especie_consulta"
]

# %%
columnas_existentes = [

    columna

    for columna in columnas

    if columna in df_registros.columns
]


df_registros = df_registros[
    columnas_existentes
]

# %% [markdown]
# ## Guardar los datos obtenidos

# %%
df_registros.to_csv(

    "Datos/registros_atelopus_colombia.csv",

    index=False
)
